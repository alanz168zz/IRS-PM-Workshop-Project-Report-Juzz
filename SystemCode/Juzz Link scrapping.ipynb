# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
URL = "https://juzzmarketingservices.com/"
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")
for a_href in soup.find_all("a", href=True):
    print(a_href["href"])
# Out:
# #
# #
# https://juzzmarketingservices.com/company-profile/
# https://juzzmarketingservices.com/contact/
# https://juzzmarketingservices.com/pdpa-compliance/
# https://wa.me/6598463760
# https://www.facebook.com/plugins/group/join/popup/?group_id=695666464610512&source=email_campaign_plugin
# https://juzzmarketingservices.com/
# https://juzzmarketingservices.com/
# https://juzzmarketingservices.com/leads-database/
# https://juzzmarketingservices.com/sms-marketing/
# https://juzzmarketingservices.com/telemarketing-singapore/
# https://juzzmarketingservices.com/flyer-printing-services/
# https://juzzmarketingservices.com/flyer-distribution/
# https://juzzmarketingservices.com/digital-marketing/
# https://juzzmarketingservices.com/blog-marketing/
# https://juzzmarketingservices.com/website-design/
# https://juzzmarketingservices.com/search-engine-optimisation/
# https://juzzmarketingservices.com/leads-for-financial-advisors/
# ...

# %%
index = ["https://juzzmarketingservices.com/company-profile/","https://juzzmarketingservices.com/contact/","https://juzzmarketingservices.com/pdpa-compliance/","https://juzzmarketingservices.com/leads-database/","https://juzzmarketingservices.com/sms-marketing/","https://juzzmarketingservices.com/telemarketing-singapore/","https://juzzmarketingservices.com/flyer-printing-services/","https://juzzmarketingservices.com/flyer-distribution/","https://juzzmarketingservices.com/digital-marketing/","https://juzzmarketingservices.com/blog-marketing/","https://juzzmarketingservices.com/website-design/","https://juzzmarketingservices.com/search-engine-optimisation/","https://juzzmarketingservices.com/leads-for-financial-advisors/","https://juzzmarketingservices.com/lead-generation-for-property-agents/","https://juzzmarketingservices.com/leads-for-business-owners/","https://juzzmarketingservices.com/case-study/","https://juzzmarketingservices.com/blog/","https://juzzmarketingservices.com/contact/","https://juzzmarketingservices.com/leads-database","https://juzzmarketingservices.com/sms-marketing","https://juzzmarketingservices.com/telemarketing-singapore","https://juzzmarketingservices.com/flyer-printing-services","https://juzzmarketingservices.com/flyer-distribution","https://juzzmarketingservices.com/digital-marketing/","https://juzzmarketingservices.com/blog-marketing/","https://juzzmarketingservices.com/website-design/","https://juzzmarketingservices.com/search-engine-optimisation/","https://juzzmarketingservices.com/leads-for-financial-advisors/","https://juzzmarketingservices.com/lead-generation-for-property-agents/","https://juzzmarketingservices.com/services/","https://juzzmarketingservices.com/careers/","https://juzzmarketingservices.com/feedback/"]
len(index)
# Out:
# 32

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
URL = "https://juzzmarketingservices.com/blog"
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")
for a_href in soup.find_all("a", href=True):
    print(a_href["href"])
# Out:
# #
# #
# https://juzzmarketingservices.com/company-profile/
# https://juzzmarketingservices.com/contact/
# https://juzzmarketingservices.com/pdpa-compliance/
# https://wa.me/6598463760
# https://www.facebook.com/plugins/group/join/popup/?group_id=695666464610512&source=email_campaign_plugin
# https://juzzmarketingservices.com/
# https://juzzmarketingservices.com/
# https://juzzmarketingservices.com/leads-database/
# https://juzzmarketingservices.com/sms-marketing/
# https://juzzmarketingservices.com/telemarketing-singapore/
# https://juzzmarketingservices.com/flyer-printing-services/
# https://juzzmarketingservices.com/flyer-distribution/
# https://juzzmarketingservices.com/digital-marketing/
# https://juzzmarketingservices.com/blog-marketing/
# https://juzzmarketingservices.com/website-design/
# https://juzzmarketingservices.com/search-engine-optimisation/
# https://juzzmarketingservices.com/leads-for-financial-advisors/
# ...
